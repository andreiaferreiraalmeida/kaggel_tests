# %% [markdown]
# # Global Food Prices
#
# Understanding how xxxxx
#
#
#
# ___________________________________________
# Author: Andreia Ferreira Almeida

# %%
# Imports
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
proj_dir = os.path.dirname(os.path.abspath("wfp_market_food_prices.csv"))
data = os.path.join(proj_dir, "wfp_market_food_prices.csv")

# %%
#Loading Data
gfp = pd.read_csv(data, engine='python')

# %% [markdown]
# ### Data Cleaning

# %%
#renameming cols
gfp.columns = ['country_id', 'country_name', 'locality_id', 'locality_name', 'market_id', 'market_name', 'commodity_purchase_id', 'commodity_purchased', 'currency_id', 'currency', 'market_type_id', 'market_type', 'measurement_id', 'unit_of_goods_measurement', 'month_recorded', 'year_recorded','mp_price:_price_paid', 'source_supplying_price_information']
gfp.columns = [x.upper() for x in gfp.columns] #inputing_uppercase

# %%
#creating a list only with id cols
id_final = [col for col in gfp.columns if col.endswith('_ID')] #removing_id_cols#1
#droping id's col since doesnt add nothing to the analysis
gfp.drop(id_final, axis=1, inplace=True)#2
gfp.rename(columns={'MARKET_TYPE':'VENDOR_TYPE'}, inplace=True)
gfp.rename(columns={'MARKET_NAME':'MARKET_SHOPS'}, inplace=True)

# %%
gfp.head()
# Out:
#   COUNTRY_NAME LOCALITY_NAME MARKET_SHOPS COMMODITY_PURCHASED CURRENCY  \
# 0  Afghanistan    Badakhshan     Fayzabad               Bread      AFN
# 1  Afghanistan    Badakhshan     Fayzabad               Bread      AFN
# 2  Afghanistan    Badakhshan     Fayzabad               Bread      AFN
# 3  Afghanistan    Badakhshan     Fayzabad               Bread      AFN
# 4  Afghanistan    Badakhshan     Fayzabad               Bread      AFN
#
#   VENDOR_TYPE UNIT_OF_GOODS_MEASUREMENT  MONTH_RECORDED  YEAR_RECORDED  \
# 0      Retail                        KG               1           2014
# 1      Retail                        KG               2           2014
# 2      Retail                        KG               3           2014
# 3      Retail                        KG               4           2014
# 4      Retail                        KG               5           2014
#
#    MP_PRICE:_PRICE_PAID SOURCE_SUPPLYING_PRICE_INFORMATION
# ...

# %%
# create dataframe without year, month and price, to obtain one entry for each different shop
gfp_unique_shop = gfp[['COUNTRY_NAME','LOCALITY_NAME','MARKET_SHOPS','VENDOR_TYPE', 'COMMODITY_PURCHASED', 'CURRENCY']]
gfp_unique_shop.head()
initialSize = gfp_unique_shop.shape[0]
#print("initial dataset size", initialSize)
gfp_unique_shop.drop_duplicates(inplace=True) # cair as colunas para poder analisar mercado único por país (mercados totais por pais)
gfp_unique_shop.reset_index(inplace=True, drop=True) #após drop_duplicates always do a reset
finalSize = gfp_unique_shop.shape[0]
#print("final dataset size, after droping duplicate lines", finalSize)

# %%
# TOP 5 alimentos mais comercializados por pais
top_5_country = gfp_unique_shop.groupby(['COUNTRY_NAME','COMMODITY_PURCHASED']) \
    .size() \
    .reset_index() \
    .rename(columns={0:'COUNT_MARKET_SELLING'}) \
    .sort_values(['COUNTRY_NAME', 'COUNT_MARKET_SELLING'], ascending=[True, False]) \
    .reset_index(drop=True)

# %% [markdown]
# #### TOP 5 de Produtos mais vendidos

# %%
#top 5 bought products
five_most_com = gfp_unique_shop['COMMODITY_PURCHASED'].value_counts().to_frame().reset_index().rename(columns={'index':'COMMODITY_PURCHASED', 'COMMODITY_PURCHASED':'COUNT'})

# %%
colors = ['b', 'g', 'r', 'c', 'm', 'y']
labels_hidden = ['', '', '', '', '']
#values = [457, 450, 432, 419, 411]
#explode = (0.2, 0, 0, 0, 0, 0)

axes = five_most_com[:5].plot.pie(y='COUNT', labels=labels_hidden, figsize=(7, 7), autopct='%1.1f%%', shadow=True)
plt.title('Quantidade de Produto mais vendida')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.legend(loc=3, labels=five_most_com[:5]['COMMODITY_PURCHASED'])
plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# #### TOP 5 de Produtos mais vendidos por país

# %%
#generating graphs for each country
country_list = top_5_country['COUNTRY_NAME'].unique()

for country in country_list:
    top_5 = top_5_country.loc[top_5_country['COUNTRY_NAME'] == country][:5]
    ax = top_5.plot(kind="bar",rot=45, color='Blue', y='COUNT_MARKET_SELLING', x='COMMODITY_PURCHASED')
    plt.title('Quantidade de Mercados que vendem o Produto no pais:' + country)
    plt.xlabel('Produto')
    plt.ylabel('Quantidade')
    ax.set_facecolor("xkcd:silver")
    plt.show()

# %% [markdown]
# #### Top5 de Moedas mais Fortes

# %%
#top 5 bought products
five_powerful_coins = gfp_unique_shop.groupby('CURRENCY').size()
five_powerful_coins.sort_values(ascending=False,inplace=True)
five_powerful_coins = five_powerful_coins.to_frame().reset_index().rename(columns={0:'TRANSACTIONS'})
five_powerful_coins[:5]
# Out:
#   CURRENCY  TRANSACTIONS
# 0      RWF          2549
# 1      XOF          1515
# 2      INR          1216
# 3      SYP           917
# 4      UAH           650

# %%
import seaborn as sns
sns.set(style="white", context="talk")

# Set up the matplotlib figure

# Generate some sequential data
x = five_powerful_coins['CURRENCY'][:5]
y1 = five_powerful_coins['TRANSACTIONS'][:5]
ax = sns.barplot(x=x, y=y1, palette="rocket")
ax.axhline(0, color="k", clip_on=False)
ax.set(ylabel="Currency transations volume")


# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
colors = ['b', 'g', 'r', 'c', 'm', 'y']
labels_hidden = ['', '', '', '', '']
#values = [457, 450, 432, 419, 411]
#explode = (0.2, 0, 0, 0, 0, 0)

axes = five_most_com[:5].plot.pie(y='COUNT', labels=labels_hidden, figsize=(7, 7), autopct='%1.1f%%', shadow=True)
plt.title('Quantidade de Produto mais vendida')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.legend(loc=3, labels=five_most_com[:5]['COMMODITY_PURCHASED'])
plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
# plot do produto mais transaccionado
gfp_Maize = gfp.loc[gfp['COMMODITY_PURCHASED'] == 'Maize']
gfp_Maize

#agrupar por cada pais e por ano e obter a média de preço por ano
gfp_Maize_grouped = gfp_Maize.groupby(['COUNTRY_NAME', 'YEAR_RECORDED'])['MP_PRICE:_PRICE_PAID'].mean().reset_index()

# serve para inspecionar a media de preço total por cada pais
#gfp_Maize_grouped_analysis = gfp_Maize.groupby(['COUNTRY_NAME'])['MP_PRICE:_PRICE_PAID'].mean().reset_index() 
# justificação da escala logaritmica, devido a valores muito dispares.

# %%
# plot
fig, ax = plt.subplots(figsize=(15,15)) # desenhar vários plots no mesmo gráfico
plt.gca().set_prop_cycle(color=['red', 'green', 'blue', 'yellow', 'purple', 'pink', 'brown', 'teal', 'orange', 'magenta', 'grey', 'turquoise', 'lavender', 'tan', 'maroon', 'olive', 'salmon', 'gold'])

for country, grp in gfp_Maize_grouped.groupby(["COUNTRY_NAME"]):
    ax = grp.plot(ax=ax, kind='line', x='YEAR_RECORDED', y='MP_PRICE:_PRICE_PAID', label=country)

ax.set_yscale("log")
plt.legend(loc='best')
plt.show()
